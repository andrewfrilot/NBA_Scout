# %%
#--Dependencies--#

#-- Data Cleaning Libraries:
import pandas as pd
import numpy as np

#-- Data Visualization Libraries:
from matplotlib import pyplot as plt
import seaborn as sns #--just in case we need it, probably won't


#-- Web Scraping Libraries:
import os
import time
import requests
from bs4 import BeautifulSoup as bs
from splinter import Browser

# %%
#Settings for accessing Website

executable_path = {"executable_path": "chromedriver.exe"}

browser = Browser ('chrome', **executable_path, headless=False)

# %%
#Create empty df
NCAA_refer = "sports-reference"
ncaa_df = pd.DataFrame()

# %%
url = "https://www.sports-reference.com/cbb/play-index/psl_finder.cgi?request=1&match=single&year_min=1993&year_max=2016&class_is_fr=Y&class_is_so=Y&class_is_jr=Y&class_is_sr=Y&pos_is_g=Y&pos_is_gf=Y&pos_is_f=Y&pos_is_fg=Y&pos_is_fc=Y&pos_is_c=Y&pos_is_cf=Y&games_type=A&c1stat=fga&c1comp=gt&order_by=year_id&order_by_asc=Y"

# %%
browser.visit(url)

# %%
browser.find_link_by_text("Next page").value
# Out:
# 'Next page'

# %%
#Clicking to the next page


def scrape_ncaa_data(page_url):
    global ncaa_df
    url = page_url
    browser.visit(url)
    click_count = 0
    
    for x in range (3):
        try:
            if click_count == 0:

                #Get html of web page
                html = browser.html

                #Read html using pandas
                read_html = pd.read_html(html)

                #Create DF and append to ncaa_df
                page_df = pd.DataFrame(read_html[1])
                ncaa_df = page_df

                #Add to click counter
                click_count += 1

                #click to go to next page
                next_page = browser.find_link_by_text("Next page")
                next_page.click()


            else:
                #Get html of web page
                html = browser.html

                #Read html using pandas
                read_html = pd.read_html(html)

                #print(read_html[1])
                page_df = pd.DataFrame(read_html[1])
                ncaa_df = ncaa_df.append(page_df, ignore_index = True)

                #click to go to next page
                next_page = browser.find_link_by_text("Next page")
                next_page.click()
        except AttributeError as error:
            print("End of scrape")
            window.close

# %%
scrape_ncaa_data(url)

# %%
ncaa_df.head()

list((ncaa_df.columns.values))
# Out:
# [('Unnamed: 0_level_0', 'Rk'),
#  ('Totals', 'Player'),
#  ('Unnamed: 2_level_0', 'Class'),
#  ('Unnamed: 3_level_0', 'Season'),
#  ('Unnamed: 4_level_0', 'Pos'),
#  ('Unnamed: 5_level_0', 'School'),
#  ('Unnamed: 6_level_0', 'Conf'),
#  ('Unnamed: 7_level_0', 'G'),
#  ('Unnamed: 8_level_0', 'MP'),
#  ('Unnamed: 9_level_0', 'FG'),
#  ('Unnamed: 10_level_0', 'FGA'),
#  ('Unnamed: 11_level_0', '2P'),
#  ('Unnamed: 12_level_0', '2PA'),
#  ('Unnamed: 13_level_0', '3P'),
#  ('Unnamed: 14_level_0', '3PA'),
#  ('Unnamed: 15_level_0', 'FT'),
#  ('Unnamed: 16_level_0', 'FTA'),
#  ('Unnamed: 17_level_0', 'ORB'),
#  ('Unnamed: 18_level_0', 'DRB'),
#  ('Unnamed: 19_level_0', 'TRB'),
#  ('Unnamed: 20_level_0', 'AST'),
#  ('Unnamed: 21_level_0', 'STL'),
#  ('Unnamed: 22_level_0', 'BLK'),
#  ('Unnamed: 23_level_0', 'TOV'),
#  ('Unnamed: 24_level_0', 'PF'),
#  ('Unnamed: 25_level_0', 'PTS')]

# %%
# #Resetting column names
ncaa_cols =["Rk", "Player", "Class", "Season", "Pos", "School", "Conf", "G", "MP", "FG", "FGA", "2P", "2PA", "3P",\
            "3PA", "FT", "FTA", "ORB", "DRB", "TRB", "AST", "STL","BLK", "TOV", "PF", "PTS"]

ncaa_df.columns = ncaa_cols
list(ncaa_df.columns.values)
ncaa_df.head()
# Out:
#   Rk             Player Class   Season Pos           School      Conf   G  \
# 0  1        Craig Aamot    SO  1992-93   G        Marquette      GMWC  20
# 1  2  Kahhar Abdul-Wali    FR  1992-93   G     Coppin State      MEAC   9
# 2  3     Abdul Abdullah    JR  1992-93   G       Providence  Big East  32
# 3  4  Shawn Abercrombie    SO  1992-93   G  St. Bonaventure      A-10   1
# 4  5      Frank Ableson    JR  1992-93   G          Cornell       Ivy  26
#
#     MP  FG ...  FTA  ORB  DRB TRB  AST STL BLK  TOV   PF  PTS
# 0  NaN   6 ...   12  NaN  NaN  22   14   1   0  NaN  NaN   24
# 1  NaN   0 ...    2  NaN  NaN   2    0   0   0  NaN  NaN    0
# 2  822  18 ...   62  NaN  NaN  55  181  30   6  NaN  NaN   69
# 3  NaN   0 ...    0  NaN  NaN   0    2   1   0  NaN  NaN    0
# 4  NaN  34 ...   33  NaN  NaN  29   50  19   3  NaN  NaN  114
#
# [5 rows x 26 columns]

# %%
#Delete Rk column
ncaa_df = ncaa_df.drop("Rk", axis =1)

# ncaa_df = ncaa_df.drop("Rk", axis =1)
ncaa_df.head()
# Out:
#               Player Class   Season Pos           School      Conf   G   MP  \
# 0        Craig Aamot    SO  1992-93   G        Marquette      GMWC  20  NaN
# 1  Kahhar Abdul-Wali    FR  1992-93   G     Coppin State      MEAC   9  NaN
# 2     Abdul Abdullah    JR  1992-93   G       Providence  Big East  32  822
# 3  Shawn Abercrombie    SO  1992-93   G  St. Bonaventure      A-10   1  NaN
# 4      Frank Ableson    JR  1992-93   G          Cornell       Ivy  26  NaN
#
#    FG FGA ...  FTA  ORB  DRB TRB  AST STL BLK  TOV   PF  PTS
# 0   6  16 ...   12  NaN  NaN  22   14   1   0  NaN  NaN   24
# 1   0   7 ...    2  NaN  NaN   2    0   0   0  NaN  NaN    0
# 2  18  75 ...   62  NaN  NaN  55  181  30   6  NaN  NaN   69
# 3   0   0 ...    0  NaN  NaN   0    2   1   0  NaN  NaN    0
# 4  34  95 ...   33  NaN  NaN  29   50  19   3  NaN  NaN  114
#
# [5 rows x 25 columns]

# %%
#Define a function to apply to Season's column of DataFrame

def normalize_year(y):
    if y == "NaN":
        return y
        
    else:
        x = y
        x = y[0:3] + x[-1]

    return x

normalize_year(ncaa_df["Season"][0])
# Out:
# '1993'

# %%
# Delete repeating columns
ncaa_df = ncaa_df[(ncaa_df.Season != "Season")]
ncaa_df
# Out:
#                   Player Class   Season  Pos                     School  \
# 0            Craig Aamot    SO  1992-93    G                  Marquette
# 1      Kahhar Abdul-Wali    FR  1992-93    G               Coppin State
# 2         Abdul Abdullah    JR  1992-93    G                 Providence
# 3      Shawn Abercrombie    SO  1992-93    G            St. Bonaventure
# 4          Frank Ableson    JR  1992-93    G                    Cornell
# 5    Ahmed Aboul-Foutouh    JR  1992-93    F                Loyola (IL)
# 6           Gerrod Abram    JR  1992-93    G             Boston College
# 7          Dexter Abrams    SR  1992-93    C           Georgia Southern
# 8          Mohammed Acha    JR  1992-93    F           Coastal Carolina
# 9            Jamal Adams    JR  1992-93    F                   Columbia
# 10           Kevin Adams    SO  1992-93    G             Texas Southern
# 11            Pete Adams    SO  1992-93    F                 Washington
# 12          Matt Adamson    SR  1992-93    G                 Notre Dame
# 13        David Adebanjo    JR  1992-93    F     Long Island University
# 14          Keith Adkins    SR  1992-93    G  North Carolina-Wilmington
# 15            Leon Agnew    FR  1992-93    C              West Virginia
# 16          Jarinn Akana    JR  1992-93    G                     Hawaii
# 17          Mark Alberts    SR  1992-93    G                      Akron
# 18        Chris Albright    SR  1992-93    C             Missouri State
# 19           Mike Alcorn    JR  1992-93    G           Youngstown State
# 20                Totals   NaN      NaN  NaN                        NaN
# 22         Jeff Aldinger    FR  1992-93    G                     Lehigh
# 23       Brandon Aldrich    JR  1992-93    G            Texas Christian
# 24     Derrick Alesivich   NaN  1992-93  NaN           Nevada-Las Vegas
# 25       Chris Alexander    FR  1992-93    C                   Virginia
# 26        Cory Alexander    SO  1992-93    G                   Virginia
# 27       Jason Alexander    SO  1992-93    G               Rhode Island
# 28        Matt Alexander    JR  1992-93    G                     Drexel
# 29     Scooter Alexander    SO  1992-93    G                     Towson
# 30        Shon Alexander    FR  1992-93    G                   Oklahoma
# ..                   ...   ...      ...  ...                        ...
# 293    Brian Bidlingmyer    SO  1992-93    F                      Siena
# 294          Ray Biggers    SO  1992-93    F                   Arkansas
# 295         Robert Biggs    SR  1992-93    F       Cal State Northridge
# 296            Ken Biley    JR  1992-93    F                   Arkansas
# 297         Chris Birden    SR  1992-93    F           Georgia Southern
# 298   Brenton Birmingham    JR  1992-93    G                  Manhattan
# 299          Tony Bishop    FR  1992-93    C              South Alabama
# 300       Donnell Bivens    JR  1992-93    F                 Iowa State
# 301          Chris Black    JR  1992-93    F                   Oklahoma
# 302               Totals   NaN      NaN  NaN                        NaN
# 304         Willie Black    JR  1992-93    G   North Carolina-Asheville
# 305      Brian Blackburn    JR  1992-93    G             Arkansas State
# 306     Kevin Blackhurst    SR  1992-93    G                   Delaware
# 307      Eric Blackiston    FR  1992-93    G                      Brown
# 308         Kim Blackner    SO  1992-93    G              Southern Utah
# 309     Kerry Blackshear    FR  1992-93    G                    Stetson
# 310    Michael Blackwell    SO  1992-93    G                   American
# 311     Robert Blackwell    FR  1992-93    F             Boston College
# 312         Joseph Blair    FR  1992-93    C                    Arizona
# 313          Scott Blair    JR  1992-93    G               Wright State
# 314           John Blake    JR  1992-93    F              South Alabama
# 315       Kenny Blakeney    SO  1992-93    G                       Duke
# 316        Ralph Blalock    FR  1992-93    F                     Towson
# 317        Martell Bland    JR  1992-93    G          Saint Mary's (CA)
# 318    Keith Blankenship   NaN  1992-93  NaN                      Akron
# 319        Joe Blasingim    SO  1992-93    G                     Baylor
# 320           Tony Block    JR  1992-93    F                       Utah
# 321        Randy Blocker    JR  1992-93    F              Northern Iowa
# 322           Jeff Bloom    JR  1992-93    F                    Liberty
# 323         Corie Blount    SR  1992-93    F                 Cincinnati
#
#           Conf    G    MP   FG  FGA ...   FTA  ORB  DRB  TRB  AST  STL  BLK  \
# 0         GMWC   20   NaN    6   16 ...    12  NaN  NaN   22   14    1    0
# 1         MEAC    9   NaN    0    7 ...     2  NaN  NaN    2    0    0    0
# 2     Big East   32   822   18   75 ...    62  NaN  NaN   55  181   30    6
# 3         A-10    1   NaN    0    0 ...     0  NaN  NaN    0    2    1    0
# 4          Ivy   26   NaN   34   95 ...    33  NaN  NaN   29   50   19    3
# 5      MW Coll    7   NaN    8   23 ...    16  NaN  NaN   20    0    2    1
# 6     Big East   20   NaN   61  143 ...    51  NaN  NaN   54   30   19    1
# 7     Southern   27   NaN  139  290 ...    65  NaN  NaN  166   22   35   11
# 8    Big South   32   NaN  182  360 ...   159  NaN  NaN  265   69   69   51
# 9          Ivy   26   NaN   40   65 ...    38  NaN  NaN   95   32   20   31
# 10        SWAC   26   NaN   46  120 ...    42  NaN  NaN   55   18   22    3
# 11      Pac-10    6   NaN    1    3 ...   NaN  NaN  NaN    3    1    1    0
# 12         Ind    6   NaN    4   11 ...     0  NaN  NaN    5    2    3    0
# 13         NEC    9   NaN   28   86 ...    25  NaN  NaN   24    8   10    1
# 14         CAA   28   NaN   85  185 ...    85  NaN  NaN   42   59   14    1
# 15        A-10   11   NaN    3    6 ...     3  NaN  NaN    7    1    1    0
# 16         WAC   28   NaN   69  151 ...    61  NaN  NaN   54   72   18    2
# 17         MAC   26   966  140  351 ...    75  NaN  NaN   47   80   23    0
# 18         MVC   31   NaN   52   97 ...    77  NaN  NaN  111   23   18   11
# 19    Mid-Cont   25   NaN   40  112 ...    31  NaN  NaN   23   26    4    0
# 20         NaN  NaN   NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 22     Patriot   14   NaN    6   14 ...     6  NaN  NaN    8   13    2    0
# 23         SWC    1   NaN    0    0 ...     0  NaN  NaN    0    1    0    0
# 24    Big West    6   NaN    0    1 ...   NaN  NaN  NaN    1    1    0    0
# 25         ACC   13    45    2    4 ...    14  NaN  NaN   13    2    0    6
# 26         ACC   31  1118  213  470 ...   132  NaN  NaN  107  144   26    7
# 27        A-10   17   NaN   39  101 ...    39  NaN  NaN   32   55   16    1
# 28         NAC   28   NaN   18   44 ...    33  NaN  NaN   32   47   19    1
# 29   Big South   27   NaN  216  430 ...   114  NaN  NaN  128   80   55    8
# 30       Big 8   20   139    8   24 ...    14  NaN  NaN   20    6   11    2
# ..         ...  ...   ...  ...  ... ...   ...  ...  ...  ...  ...  ...  ...
# 293       MAAC   29   NaN   26   97 ...    28  NaN  NaN   63   21   14    6
# 294        SEC   25   189   16   36 ...     8  NaN  NaN   37   10    6    6
# 295        Ind   18   NaN    4   14 ...     9  NaN  NaN   21    1    1    2
# 296        SEC   19   155   16   38 ...    24  NaN  NaN   48   11    7    9
# 297   Southern   28   NaN   62   96 ...    75  NaN  NaN   85   16   12    3
# 298       MAAC   30   NaN  112  222 ...    70  NaN  NaN  101   54   44    7
# 299   Sun Belt   18   NaN    9   23 ...    20  NaN  NaN   33    0    3    0
# 300      Big 8   19    83   14   31 ...    10  NaN  NaN   19    5    6    3
# 301      Big 8   12    37    4   12 ...     4  NaN  NaN    9    2    2    1
# 302        NaN  NaN   NaN  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 304  Big South   14   NaN   40  130 ...    25  NaN  NaN   51   28   14    0
# 305   Sun Belt   11    18    2    8 ...     0  NaN  NaN    4    0    0    1
# 306        NAC   30   NaN   82  226 ...    77  NaN  NaN  127   57   51    6
# 307        Ivy   26   NaN   88  236 ...   135  NaN  NaN   89   85   25   12
# 308        Ind   23   NaN   18   44 ...    13  NaN  NaN   48   16    9    0
# 309       TAAC   27   NaN  161  317 ...   105  NaN  NaN  139   21   27    9
# 310        CAA   27   NaN   34   90 ...    13  NaN  NaN   63   11    8    6
# 311   Big East   21   NaN   18   36 ...    10  NaN  NaN   17    4    2    2
# 312     Pac-10   28   NaN   86  132 ...    47  NaN  NaN  107   12    5   10
# 313   Mid-Cont   10   NaN    2    9 ...    10  NaN  NaN    3    3    4    2
# 314   Sun Belt   26   NaN  119  192 ...    85  NaN  NaN  137   36   10    7
# 315        ACC   30   305   32   77 ...    29  NaN  NaN   45   20   11    1
# 316  Big South   27   NaN   39   90 ...    28  NaN  NaN   53   18   11    5
# 317        WCC   20   NaN   33   81 ...    37  NaN  NaN   38   39   19    6
# 318        MAC    3    12    0    2 ...     2  NaN  NaN    1    0    0    2
# 319        SWC   24   409   46  133 ...    72  NaN  NaN   43   49   19    6
# 320        WAC   31   NaN   62  115 ...    30  NaN  NaN   96   24   15   15
# 321        MVC   27   NaN  201  393 ...   145  NaN  NaN  195   31   24   12
# 322  Big South   23   NaN   21   52 ...     9  NaN  NaN   24   15    4    0
# 323       GMWC   21   588  104  189 ...    53  NaN  NaN  170   47   37   33
#
#      TOV   PF  PTS
# 0    NaN  NaN   24
# 1    NaN  NaN    0
# 2    NaN  NaN   69
# 3    NaN  NaN    0
# 4    NaN  NaN  114
# 5    NaN  NaN   24
# 6    NaN  NaN  192
# 7    NaN  NaN  328
# 8    NaN  NaN  478
# 9    NaN  NaN  101
# 10   NaN  NaN  144
# 11   NaN  NaN    2
# 12   NaN  NaN   11
# 13   NaN  NaN   86
# 14   NaN  NaN  307
# 15   NaN  NaN    7
# 16   NaN  NaN  198
# 17    52   34  444
# 18   NaN  NaN  155
# 19   NaN  NaN  135
# 20   NaN  NaN  NaN
# 22   NaN  NaN   19
# 23   NaN  NaN    0
# 24   NaN  NaN    0
# 25     2   11    7
# 26   106   75  583
# 27   NaN  NaN  123
# 28   NaN  NaN   48
# 29   NaN  NaN  522
# 30     9   21   26
# ..   ...  ...  ...
# 293  NaN  NaN   78
# 294   13   16   33
# 295  NaN  NaN   11
# 296   10   22   45
# 297  NaN  NaN  170
# 298  NaN  NaN  322
# 299  NaN  NaN   34
# 300    3   10   35
# 301    3    4   11
# 302  NaN  NaN  NaN
# 304  NaN  NaN  121
# 305    0    2    4
# 306  NaN  NaN  246
# 307  NaN  NaN  282
# 308  NaN  NaN   54
# 309  NaN  NaN  451
# 310  NaN  NaN   70
# 311  NaN  NaN   42
# 312  NaN  NaN  200
# 313  NaN  NaN    8
# 314  NaN  NaN  305
# 315   33   32   87
# 316  NaN  NaN  105
# 317  NaN  NaN   96
# 318    1    5    1
# 319   41   44  162
# 320  NaN  NaN  145
# 321  NaN  NaN  509
# 322  NaN  NaN   58
# 323   54   69  238
#
# [312 rows x 25 columns]

# %%
#Replace NaN values with 0

ncaa_df = ncaa_df.fillna(0)
ncaa_df.head()
# Out:
#               Player Class   Season Pos           School      Conf   G   MP  \
# 0        Craig Aamot    SO  1992-93   G        Marquette      GMWC  20    0
# 1  Kahhar Abdul-Wali    FR  1992-93   G     Coppin State      MEAC   9    0
# 2     Abdul Abdullah    JR  1992-93   G       Providence  Big East  32  822
# 3  Shawn Abercrombie    SO  1992-93   G  St. Bonaventure      A-10   1    0
# 4      Frank Ableson    JR  1992-93   G          Cornell       Ivy  26    0
#
#    FG FGA ...  FTA ORB DRB TRB  AST STL BLK TOV PF  PTS
# 0   6  16 ...   12   0   0  22   14   1   0   0  0   24
# 1   0   7 ...    2   0   0   2    0   0   0   0  0    0
# 2  18  75 ...   62   0   0  55  181  30   6   0  0   69
# 3   0   0 ...    0   0   0   0    2   1   0   0  0    0
# 4  34  95 ...   33   0   0  29   50  19   3   0  0  114
#
# [5 rows x 25 columns]
